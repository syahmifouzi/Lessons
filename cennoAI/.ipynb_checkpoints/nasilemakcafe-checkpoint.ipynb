# %%
from fastai.imports import *

# %%
# Parameters
days = 90  # Simulate for 30 days
base_customers = 50  # Base number of customers per day
marketing_factor = 1.2  # 20% increase due to marketing
competition_factor = 0.9  # 10% decrease due to competition
seasonality_factor = np.sin(np.linspace(0, 2 * np.pi, days)) * 0.1 + 1  # Seasonal variations
random_variability = np.random.normal(1, 0.1, days)  # Random variability with 10% standard deviation

# %%
# Calculate daily customers
daily_customers = base_customers * marketing_factor * competition_factor * seasonality_factor * random_variability

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(daily_customers, label='Daily Customers')
plt.xlabel('Day')
plt.ylabel('Number of Customers')
plt.title('Simulated Number of Customers for Newly Opened Café')
plt.legend()
plt.show()

# %%
daily_customers
# Out:
# array([55.40177553, 48.7195188 , 58.44952128, 51.88781615, 56.80761632,
#        69.69982205, 62.94513277, 52.37565658, 56.51734066, 64.19888376,
#        53.27257604, 51.39746573, 57.49202932, 51.95094939, 43.811638  ,
#        47.58554595, 59.28117768, 50.38678682, 51.41767284, 45.18121547,
#        45.55361829, 49.79695347, 51.34508193, 49.28702163, 47.03108294,
#        56.69904953, 55.14712909, 44.62858331, 52.82960027, 54.31472753])
